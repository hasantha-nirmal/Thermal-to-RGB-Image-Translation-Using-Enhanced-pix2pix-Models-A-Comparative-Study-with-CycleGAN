# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd 'drive/MyDrive/video_and_img_process/assign2/thermal_rgb/'
# Out:
# /content/drive/MyDrive/video_and_img_process/assign2/thermal_rgb

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import random

# Load and preprocess images from 'thermal_8_bit' and 'RGB' folders
imgs_folder_1 = "LLVIP/visible/train"
imgs_folder_2 = "LLVIP/infrared/train"

# def get_image_filenames(folder_path):
#     filenames = sorted(os.listdir(folder_path))[:500]
#     image_filenames = [filename for filename in filenames if filename.endswith(('.jpeg', '.jpg', '.png'))]
#     return image_filenames

# img_names_fld1=get_image_filenames(imgs_folder_1)
# img_names_fld2=get_image_filenames(imgs_folder_2)

def get_random_image_filenames(folder_path, num_samples):
    filenames = os.listdir(folder_path)
    random.shuffle(filenames)  # Shuffle the filenames list
    filenames = filenames[:num_samples]  # Take a random sample
    image_filenames = [filename for filename in filenames if filename.endswith(('.jpeg', '.jpg', '.png'))]
    return image_filenames

num_samples = 500  # Number of random samples to take

# Get random samples for both folders using the same shuffled list
shuffled_filenames = get_random_image_filenames(imgs_folder_1, num_samples)
img_names_fld1 = shuffled_filenames[:]
img_names_fld2 = shuffled_filenames[:]


def common_filenames_and_sort(filenames_1, filenames_2):
    # Convert the filenames lists to sets for efficient intersection
    set_filenames_1 = {os.path.splitext(filename)[0] for filename in filenames_1}
    set_filenames_2 = {os.path.splitext(filename)[0] for filename in filenames_2}

    # Find common filenames
    common_filenames = set_filenames_1.intersection(set_filenames_2)

    # Sort the common filenames
    sorted_common_filenames = sorted(common_filenames)

    # Return the sorted common filenames
    return sorted_common_filenames

common_img_names = common_filenames_and_sort(img_names_fld1, img_names_fld2)

def load_common_images(folder_path, common_filenames, target_size=(256,256)):
    images = []
    for filename in common_filenames:
        # Iterate over possible extensions
        for ext in ['.jpg', '.jpeg','.png']:
            img_path = os.path.join(folder_path, filename + ext)
            if os.path.exists(img_path):
                # Read image
                img = cv2.imread(img_path)
                if img is not None:  # Check if image is successfully loaded
                    print('Image loaded successfully:', img_path)
                    # Resize image
                    img = cv2.resize(img, target_size)
                    #img= cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    images.append(img)
                    break  # Exit loop if image is successfully loaded
                else:
                    print('Error: Unable to load image', img_path)
    return images

# def apply_thermal_filter(images):
#     filtered_images = []
#     for img in images:
#         # Convert image to grayscale
#         gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

#         # Apply thermal filter
#         thermal_img = cv2.applyColorMap(gray_img, cv2.COLORMAP_JET)

#         filtered_images.append(thermal_img)

#     return np.array(filtered_images)

imgs_data = load_common_images(imgs_folder_1, common_img_names , target_size=(256,256))
labels_data = load_common_images(imgs_folder_2, common_img_names , target_size=(256, 256))
#labels_data=apply_thermal_filter(imgs_data )

# Convert lists to numpy arrays
imgs_data = np.array(imgs_data)
labels_data = np.array(labels_data)

# Data augmentation function for horizontal flipping
def horizontal_flip(images, labels):
    augmented_images = []
    augmented_labels = []
    for img, label in zip(images, labels):
        # Flip image horizontally
        flipped_img = cv2.flip(img, 1)
        flipped_label = cv2.flip(label, 1)
        augmented_images.append(flipped_img)
        augmented_labels.append(flipped_label)  # Label remains the same for flipped image
    return augmented_images, augmented_labels

# Data augmentation function for image shifting
def image_shift(images, labels, shift_range=20):
    augmented_images = []
    augmented_labels = []
    for img, label in zip(images, labels):
        # Generate random shift values
        dx = np.random.randint(-shift_range, shift_range)
        dy = np.random.randint(-shift_range, shift_range)

        # Create translation matrix
        M = np.float32([[1, 0, dx], [0, 1, dy]])

        # Shift image and label
        shifted_img = cv2.warpAffine(img, M, (img.shape[1], img.shape[0]))
        shifted_label = cv2.warpAffine(label, M, (label.shape[1], label.shape[0]))

        augmented_images.append(shifted_img)
        augmented_labels.append(shifted_label)
    return augmented_images, augmented_labels

# Data augmentation function for vertical flipping
def vertical_flip(images, labels):
    augmented_images = []
    augmented_labels = []
    for img, label in zip(images, labels):
        # Flip image vertically
        flipped_img = cv2.flip(img, 0)
        flipped_label = cv2.flip(label, 0)
        augmented_images.append(flipped_img)
        augmented_labels.append(flipped_label)  # Label remains the same for flipped image
    return augmented_images, augmented_labels

# Perform data augmentation
augmented_imgs_data, augmented_labels_data = horizontal_flip(imgs_data, labels_data)
shifted_imgs, shifted_labels = image_shift(imgs_data, labels_data)
vertical_flipped_imgs, vertical_flipped_labels = vertical_flip(imgs_data, labels_data)

# Concatenate augmented data with original data
augmented_imgs_data = np.concatenate([imgs_data, augmented_imgs_data, shifted_imgs, vertical_flipped_imgs])
augmented_labels_data = np.concatenate([labels_data, augmented_labels_data, shifted_labels, vertical_flipped_labels])

# # Shuffle augmented data
shuffle_indices = np.random.permutation(len(augmented_imgs_data))
augmented_imgs_data = augmented_imgs_data[shuffle_indices]
augmented_labels_data = augmented_labels_data[shuffle_indices]

# # # Convert to float and normalize
augmented_imgs_data = augmented_imgs_data.astype(np.float32) / 255.0
augmented_labels_data = augmented_labels_data.astype(np.float32) / 255.0

# Display the shape of the augmented arrays
print("Augmented Images array shape:", augmented_imgs_data.shape)
print("Augmented Labels array shape:", augmented_labels_data.shape)
# Out:
# Image loaded successfully: LLVIP/visible/train/010007.jpg
# Image loaded successfully: LLVIP/visible/train/010016.jpg
# Image loaded successfully: LLVIP/visible/train/010022.jpg
# Image loaded successfully: LLVIP/visible/train/010045.jpg
# Image loaded successfully: LLVIP/visible/train/010048.jpg
# Image loaded successfully: LLVIP/visible/train/010057.jpg
# Image loaded successfully: LLVIP/visible/train/010066.jpg
# Image loaded successfully: LLVIP/visible/train/010072.jpg
# Image loaded successfully: LLVIP/visible/train/010100.jpg
# Image loaded successfully: LLVIP/visible/train/010104.jpg
# Image loaded successfully: LLVIP/visible/train/010109.jpg
# Image loaded successfully: LLVIP/visible/train/010114.jpg
# Image loaded successfully: LLVIP/visible/train/010116.jpg
# Image loaded successfully: LLVIP/visible/train/010126.jpg
# Image loaded successfully: LLVIP/visible/train/010139.jpg
# Image loaded successfully: LLVIP/visible/train/010161.jpg
# Image loaded successfully: LLVIP/visible/train/010168.jpg
# Image loaded successfully: LLVIP/visible/train/010171.jpg
# Image loaded successfully: LLVIP/visible/train/010173.jpg
# Image loaded successfully: LLVIP/visible/train/010204.jpg
# Image loaded successfully: LLVIP/visible/train/010215.jpg
# Image loaded successfully: LLVIP/visible/train/010236.jpg
# Image loaded successfully: LLVIP/visible/train/010238.jpg
# Image loaded successfully: LLVIP/visible/train/010241.jpg
# Image loaded successfully: LLVIP/visible/train/010243.jpg
# Image loaded successfully: LLVIP/visible/train/010245.jpg
# Image loaded successfully: LLVIP/visible/train/010250.jpg
# Image loaded successfully: LLVIP/visible/train/010262.jpg
# Image loaded successfully: LLVIP/visible/train/010273.jpg
# Image loaded successfully: LLVIP/visible/train/010275.jpg
# Image loaded successfully: LLVIP/visible/train/010278.jpg
# Image loaded successfully: LLVIP/visible/train/010293.jpg
# Image loaded successfully: LLVIP/visible/train/010312.jpg
# Image loaded successfully: LLVIP/visible/train/010313.jpg
# Image loaded successfully: LLVIP/visible/train/010324.jpg
# Image loaded successfully: LLVIP/visible/train/010335.jpg
# Image loaded successfully: LLVIP/visible/train/010339.jpg
# Image loaded successfully: LLVIP/visible/train/010357.jpg
# Image loaded successfully: LLVIP/visible/train/010363.jpg
# Image loaded successfully: LLVIP/visible/train/010372.jpg
# Image loaded successfully: LLVIP/visible/train/010380.jpg
# Image loaded successfully: LLVIP/visible/train/010398.jpg
# Image loaded successfully: LLVIP/visible/train/010399.jpg
# Image loaded successfully: LLVIP/visible/train/010404.jpg
# Image loaded successfully: LLVIP/visible/train/010406.jpg
# Image loaded successfully: LLVIP/visible/train/010409.jpg
# Image loaded successfully: LLVIP/visible/train/010424.jpg
# Image loaded successfully: LLVIP/visible/train/010431.jpg
# Image loaded successfully: LLVIP/visible/train/010432.jpg
# Image loaded successfully: LLVIP/visible/train/010473.jpg
# Image loaded successfully: LLVIP/visible/train/010478.jpg
# Image loaded successfully: LLVIP/visible/train/010479.jpg
# Image loaded successfully: LLVIP/visible/train/010480.jpg
# Image loaded successfully: LLVIP/visible/train/010481.jpg
# Image loaded successfully: LLVIP/visible/train/010494.jpg
# Image loaded successfully: LLVIP/visible/train/010504.jpg
# Image loaded successfully: LLVIP/visible/train/010507.jpg
# Image loaded successfully: LLVIP/visible/train/010511.jpg
# Image loaded successfully: LLVIP/visible/train/010513.jpg
# Image loaded successfully: LLVIP/visible/train/010529.jpg
# Image loaded successfully: LLVIP/visible/train/010530.jpg
# Image loaded successfully: LLVIP/visible/train/010538.jpg
# Image loaded successfully: LLVIP/visible/train/010543.jpg
# Image loaded successfully: LLVIP/visible/train/010546.jpg
# Image loaded successfully: LLVIP/visible/train/010547.jpg
# Image loaded successfully: LLVIP/visible/train/010551.jpg
# Image loaded successfully: LLVIP/visible/train/010560.jpg
# Image loaded successfully: LLVIP/visible/train/010565.jpg
# Image loaded successfully: LLVIP/visible/train/010578.jpg
# Image loaded successfully: LLVIP/visible/train/010591.jpg
# Image loaded successfully: LLVIP/visible/train/010595.jpg
# Image loaded successfully: LLVIP/visible/train/010596.jpg
# Image loaded successfully: LLVIP/visible/train/020019.jpg
# Image loaded successfully: LLVIP/visible/train/020031.jpg
# Image loaded successfully: LLVIP/visible/train/020038.jpg
# Image loaded successfully: LLVIP/visible/train/020061.jpg
# Image loaded successfully: LLVIP/visible/train/020065.jpg
# Image loaded successfully: LLVIP/visible/train/020081.jpg
# Image loaded successfully: LLVIP/visible/train/020088.jpg
# Image loaded successfully: LLVIP/visible/train/020090.jpg
# Image loaded successfully: LLVIP/visible/train/020105.jpg
# Image loaded successfully: LLVIP/visible/train/020116.jpg
# Image loaded successfully: LLVIP/visible/train/020121.jpg
# Image loaded successfully: LLVIP/visible/train/020131.jpg
# Image loaded successfully: LLVIP/visible/train/020148.jpg
# Image loaded successfully: LLVIP/visible/train/020157.jpg
# Image loaded successfully: LLVIP/visible/train/020161.jpg
# Image loaded successfully: LLVIP/visible/train/020166.jpg
# Image loaded successfully: LLVIP/visible/train/020167.jpg
# Image loaded successfully: LLVIP/visible/train/020170.jpg
# Image loaded successfully: LLVIP/visible/train/020172.jpg
# Image loaded successfully: LLVIP/visible/train/020173.jpg
# Image loaded successfully: LLVIP/visible/train/020176.jpg
# Image loaded successfully: LLVIP/visible/train/020191.jpg
# Image loaded successfully: LLVIP/visible/train/020199.jpg
# Image loaded successfully: LLVIP/visible/train/020228.jpg
# Image loaded successfully: LLVIP/visible/train/020241.jpg
# Image loaded successfully: LLVIP/visible/train/020243.jpg
# Image loaded successfully: LLVIP/visible/train/020265.jpg
# Image loaded successfully: LLVIP/visible/train/020273.jpg
# Image loaded successfully: LLVIP/visible/train/020285.jpg
# Image loaded successfully: LLVIP/visible/train/020299.jpg
# Image loaded successfully: LLVIP/visible/train/020304.jpg
# Image loaded successfully: LLVIP/visible/train/020306.jpg
# Image loaded successfully: LLVIP/visible/train/020307.jpg
# Image loaded successfully: LLVIP/visible/train/020309.jpg
# Image loaded successfully: LLVIP/visible/train/020317.jpg
# Image loaded successfully: LLVIP/visible/train/020338.jpg
# Image loaded successfully: LLVIP/visible/train/020344.jpg
# Image loaded successfully: LLVIP/visible/train/020345.jpg
# Image loaded successfully: LLVIP/visible/train/020351.jpg
# Image loaded successfully: LLVIP/visible/train/020358.jpg
# Image loaded successfully: LLVIP/visible/train/020388.jpg
# Image loaded successfully: LLVIP/visible/train/020420.jpg
# Image loaded successfully: LLVIP/visible/train/020434.jpg
# Image loaded successfully: LLVIP/visible/train/020435.jpg
# Image loaded successfully: LLVIP/visible/train/020439.jpg
# Image loaded successfully: LLVIP/visible/train/020444.jpg
# Image loaded successfully: LLVIP/visible/train/020488.jpg
# Image loaded successfully: LLVIP/visible/train/020497.jpg
# Image loaded successfully: LLVIP/visible/train/030011.jpg
# Image loaded successfully: LLVIP/visible/train/030023.jpg
# Image loaded successfully: LLVIP/visible/train/030026.jpg
# Image loaded successfully: LLVIP/visible/train/030048.jpg
# Image loaded successfully: LLVIP/visible/train/030064.jpg
# Image loaded successfully: LLVIP/visible/train/030069.jpg
# Image loaded successfully: LLVIP/visible/train/030075.jpg
# Image loaded successfully: LLVIP/visible/train/030083.jpg
# Image loaded successfully: LLVIP/visible/train/030092.jpg
# Image loaded successfully: LLVIP/visible/train/030115.jpg
# Image loaded successfully: LLVIP/visible/train/030121.jpg
# Image loaded successfully: LLVIP/visible/train/030127.jpg
# Image loaded successfully: LLVIP/visible/train/030144.jpg
# Image loaded successfully: LLVIP/visible/train/030145.jpg
# Image loaded successfully: LLVIP/visible/train/030153.jpg
# Image loaded successfully: LLVIP/visible/train/030182.jpg
# Image loaded successfully: LLVIP/visible/train/030184.jpg
# Image loaded successfully: LLVIP/visible/train/030198.jpg
# Image loaded successfully: LLVIP/visible/train/030216.jpg
# Image loaded successfully: LLVIP/visible/train/030221.jpg
# Image loaded successfully: LLVIP/visible/train/030254.jpg
# Image loaded successfully: LLVIP/visible/train/030261.jpg
# Image loaded successfully: LLVIP/visible/train/030266.jpg
# Image loaded successfully: LLVIP/visible/train/030267.jpg
# Image loaded successfully: LLVIP/visible/train/030271.jpg
# Image loaded successfully: LLVIP/visible/train/030276.jpg
# Image loaded successfully: LLVIP/visible/train/030281.jpg
# Image loaded successfully: LLVIP/visible/train/030287.jpg
# Image loaded successfully: LLVIP/visible/train/030290.jpg
# Image loaded successfully: LLVIP/visible/train/030299.jpg
# Image loaded successfully: LLVIP/visible/train/030304.jpg
# Image loaded successfully: LLVIP/visible/train/030321.jpg
# Image loaded successfully: LLVIP/visible/train/030323.jpg
# Image loaded successfully: LLVIP/visible/train/030330.jpg
# Image loaded successfully: LLVIP/visible/train/030336.jpg
# Image loaded successfully: LLVIP/visible/train/030346.jpg
# Image loaded successfully: LLVIP/visible/train/030364.jpg
# Image loaded successfully: LLVIP/visible/train/030369.jpg
# Image loaded successfully: LLVIP/visible/train/030381.jpg
# Image loaded successfully: LLVIP/visible/train/030414.jpg
# Image loaded successfully: LLVIP/visible/train/030419.jpg
# Image loaded successfully: LLVIP/visible/train/030422.jpg
# Image loaded successfully: LLVIP/visible/train/030435.jpg
# Image loaded successfully: LLVIP/visible/train/030455.jpg
# Image loaded successfully: LLVIP/visible/train/030457.jpg
# Image loaded successfully: LLVIP/visible/train/030458.jpg
# Image loaded successfully: LLVIP/visible/train/040005.jpg
# Image loaded successfully: LLVIP/visible/train/040009.jpg
# Image loaded successfully: LLVIP/visible/train/040036.jpg
# Image loaded successfully: LLVIP/visible/train/040038.jpg
# Image loaded successfully: LLVIP/visible/train/040044.jpg
# Image loaded successfully: LLVIP/visible/train/040054.jpg
# Image loaded successfully: LLVIP/visible/train/040063.jpg
# Image loaded successfully: LLVIP/visible/train/040066.jpg
# Image loaded successfully: LLVIP/visible/train/040070.jpg
# Image loaded successfully: LLVIP/visible/train/040073.jpg
# Image loaded successfully: LLVIP/visible/train/040088.jpg
# Image loaded successfully: LLVIP/visible/train/040092.jpg
# Image loaded successfully: LLVIP/visible/train/040096.jpg
# Image loaded successfully: LLVIP/visible/train/040100.jpg
# Image loaded successfully: LLVIP/visible/train/040117.jpg
# Image loaded successfully: LLVIP/visible/train/040119.jpg
# Image loaded successfully: LLVIP/visible/train/040154.jpg
# Image loaded successfully: LLVIP/visible/train/040171.jpg
# Image loaded successfully: LLVIP/visible/train/040189.jpg
# Image loaded successfully: LLVIP/visible/train/040193.jpg
# Image loaded successfully: LLVIP/visible/train/040199.jpg
# Image loaded successfully: LLVIP/visible/train/040201.jpg
# Image loaded successfully: LLVIP/visible/train/040202.jpg
# Image loaded successfully: LLVIP/visible/train/040222.jpg
# Image loaded successfully: LLVIP/visible/train/040225.jpg
# Image loaded successfully: LLVIP/visible/train/040234.jpg
# Image loaded successfully: LLVIP/visible/train/040242.jpg
# Image loaded successfully: LLVIP/visible/train/040260.jpg
# Image loaded successfully: LLVIP/visible/train/040262.jpg
# Image loaded successfully: LLVIP/visible/train/040272.jpg
# Image loaded successfully: LLVIP/visible/train/040284.jpg
# Image loaded successfully: LLVIP/visible/train/040297.jpg
# Image loaded successfully: LLVIP/visible/train/040313.jpg
# Image loaded successfully: LLVIP/visible/train/040321.jpg
# Image loaded successfully: LLVIP/visible/train/040323.jpg
# Image loaded successfully: LLVIP/visible/train/040327.jpg
# Image loaded successfully: LLVIP/visible/train/040339.jpg
# Image loaded successfully: LLVIP/visible/train/040346.jpg
# Image loaded successfully: LLVIP/visible/train/040348.jpg
# Image loaded successfully: LLVIP/visible/train/040357.jpg
# Image loaded successfully: LLVIP/visible/train/040363.jpg
# Image loaded successfully: LLVIP/visible/train/040366.jpg
# Image loaded successfully: LLVIP/visible/train/040373.jpg
# Image loaded successfully: LLVIP/visible/train/040381.jpg
# Image loaded successfully: LLVIP/visible/train/040388.jpg
# Image loaded successfully: LLVIP/visible/train/040401.jpg
# Image loaded successfully: LLVIP/visible/train/040428.jpg
# Image loaded successfully: LLVIP/visible/train/040433.jpg
# Image loaded successfully: LLVIP/visible/train/040441.jpg
# Image loaded successfully: LLVIP/visible/train/040442.jpg
# Image loaded successfully: LLVIP/visible/train/040444.jpg
# Image loaded successfully: LLVIP/visible/train/040448.jpg
# Image loaded successfully: LLVIP/visible/train/040461.jpg
# Image loaded successfully: LLVIP/visible/train/050031.jpg
# Image loaded successfully: LLVIP/visible/train/050032.jpg
# Image loaded successfully: LLVIP/visible/train/050036.jpg
# Image loaded successfully: LLVIP/visible/train/050041.jpg
# Image loaded successfully: LLVIP/visible/train/050046.jpg
# Image loaded successfully: LLVIP/visible/train/050062.jpg
# Image loaded successfully: LLVIP/visible/train/050064.jpg
# Image loaded successfully: LLVIP/visible/train/050067.jpg
# Image loaded successfully: LLVIP/visible/train/050070.jpg
# Image loaded successfully: LLVIP/visible/train/050084.jpg
# Image loaded successfully: LLVIP/visible/train/050085.jpg
# Image loaded successfully: LLVIP/visible/train/050086.jpg
# Image loaded successfully: LLVIP/visible/train/050097.jpg
# Image loaded successfully: LLVIP/visible/train/050103.jpg
# Image loaded successfully: LLVIP/visible/train/050105.jpg
# Image loaded successfully: LLVIP/visible/train/050110.jpg
# Image loaded successfully: LLVIP/visible/train/050118.jpg
# Image loaded successfully: LLVIP/visible/train/050121.jpg
# Image loaded successfully: LLVIP/visible/train/050124.jpg
# Image loaded successfully: LLVIP/visible/train/050135.jpg
# Image loaded successfully: LLVIP/visible/train/050136.jpg
# Image loaded successfully: LLVIP/visible/train/050145.jpg
# Image loaded successfully: LLVIP/visible/train/050150.jpg
# Image loaded successfully: LLVIP/visible/train/050155.jpg
# Image loaded successfully: LLVIP/visible/train/050160.jpg
# Image loaded successfully: LLVIP/visible/train/050179.jpg
# Image loaded successfully: LLVIP/visible/train/050187.jpg
# Image loaded successfully: LLVIP/visible/train/050188.jpg
# Image loaded successfully: LLVIP/visible/train/050214.jpg
# Image loaded successfully: LLVIP/visible/train/050220.jpg
# Image loaded successfully: LLVIP/visible/train/050226.jpg
# Image loaded successfully: LLVIP/visible/train/050228.jpg
# Image loaded successfully: LLVIP/visible/train/050230.jpg
# Image loaded successfully: LLVIP/visible/train/050250.jpg
# Image loaded successfully: LLVIP/visible/train/050266.jpg
# Image loaded successfully: LLVIP/visible/train/050269.jpg
# Image loaded successfully: LLVIP/visible/train/050273.jpg
# Image loaded successfully: LLVIP/visible/train/050276.jpg
# Image loaded successfully: LLVIP/visible/train/050290.jpg
# Image loaded successfully: LLVIP/visible/train/050306.jpg
# Image loaded successfully: LLVIP/visible/train/050311.jpg
# Image loaded successfully: LLVIP/visible/train/050315.jpg
# Image loaded successfully: LLVIP/visible/train/050342.jpg
# Image loaded successfully: LLVIP/visible/train/050345.jpg
# Image loaded successfully: LLVIP/visible/train/050359.jpg
# Image loaded successfully: LLVIP/visible/train/050364.jpg
# Image loaded successfully: LLVIP/visible/train/050366.jpg
# Image loaded successfully: LLVIP/visible/train/050373.jpg
# Image loaded successfully: LLVIP/visible/train/050383.jpg
# Image loaded successfully: LLVIP/visible/train/050392.jpg
# Image loaded successfully: LLVIP/visible/train/050404.jpg
# Image loaded successfully: LLVIP/visible/train/050410.jpg
# Image loaded successfully: LLVIP/visible/train/050411.jpg
# Image loaded successfully: LLVIP/visible/train/050415.jpg
# Image loaded successfully: LLVIP/visible/train/050416.jpg
# Image loaded successfully: LLVIP/visible/train/050425.jpg
# Image loaded successfully: LLVIP/visible/train/050428.jpg
# Image loaded successfully: LLVIP/visible/train/060003.jpg
# Image loaded successfully: LLVIP/visible/train/060033.jpg
# Image loaded successfully: LLVIP/visible/train/060069.jpg
# Image loaded successfully: LLVIP/visible/train/060088.jpg
# Image loaded successfully: LLVIP/visible/train/060097.jpg
# Image loaded successfully: LLVIP/visible/train/060102.jpg
# Image loaded successfully: LLVIP/visible/train/060129.jpg
# Image loaded successfully: LLVIP/visible/train/060135.jpg
# Image loaded successfully: LLVIP/visible/train/060137.jpg
# Image loaded successfully: LLVIP/visible/train/060144.jpg
# Image loaded successfully: LLVIP/visible/train/060150.jpg
# Image loaded successfully: LLVIP/visible/train/060154.jpg
# Image loaded successfully: LLVIP/visible/train/060155.jpg
# Image loaded successfully: LLVIP/visible/train/060167.jpg
# Image loaded successfully: LLVIP/visible/train/060180.jpg
# Image loaded successfully: LLVIP/visible/train/060181.jpg
# Image loaded successfully: LLVIP/visible/train/060190.jpg
# Image loaded successfully: LLVIP/visible/train/060196.jpg
# Image loaded successfully: LLVIP/visible/train/060200.jpg
# Image loaded successfully: LLVIP/visible/train/060228.jpg
# Image loaded successfully: LLVIP/visible/train/060253.jpg
# Image loaded successfully: LLVIP/visible/train/060258.jpg
# Image loaded successfully: LLVIP/visible/train/060263.jpg
# Image loaded successfully: LLVIP/visible/train/060267.jpg
# Image loaded successfully: LLVIP/visible/train/060269.jpg
# Image loaded successfully: LLVIP/visible/train/060280.jpg
# Image loaded successfully: LLVIP/visible/train/060283.jpg
# Image loaded successfully: LLVIP/visible/train/060291.jpg
# Image loaded successfully: LLVIP/visible/train/060292.jpg
# Image loaded successfully: LLVIP/visible/train/060293.jpg
# Image loaded successfully: LLVIP/visible/train/060294.jpg
# Image loaded successfully: LLVIP/visible/train/060304.jpg
# Image loaded successfully: LLVIP/visible/train/060313.jpg
# Image loaded successfully: LLVIP/visible/train/060318.jpg
# Image loaded successfully: LLVIP/visible/train/060326.jpg
# Image loaded successfully: LLVIP/visible/train/060341.jpg
# Image loaded successfully: LLVIP/visible/train/060350.jpg
# Image loaded successfully: LLVIP/visible/train/060358.jpg
# Image loaded successfully: LLVIP/visible/train/060360.jpg
# Image loaded successfully: LLVIP/visible/train/060366.jpg
# Image loaded successfully: LLVIP/visible/train/060367.jpg
# Image loaded successfully: LLVIP/visible/train/060379.jpg
# Image loaded successfully: LLVIP/visible/train/060395.jpg
# Image loaded successfully: LLVIP/visible/train/060397.jpg
# Image loaded successfully: LLVIP/visible/train/060402.jpg
# Image loaded successfully: LLVIP/visible/train/060412.jpg
# Image loaded successfully: LLVIP/visible/train/060416.jpg
# Image loaded successfully: LLVIP/visible/train/060418.jpg
# Image loaded successfully: LLVIP/visible/train/060421.jpg
# Image loaded successfully: LLVIP/visible/train/060436.jpg
# Image loaded successfully: LLVIP/visible/train/060444.jpg
# Image loaded successfully: LLVIP/visible/train/060454.jpg
# Image loaded successfully: LLVIP/visible/train/060456.jpg
# Image loaded successfully: LLVIP/visible/train/060464.jpg
# Image loaded successfully: LLVIP/visible/train/060474.jpg
# Image loaded successfully: LLVIP/visible/train/060508.jpg
# Image loaded successfully: LLVIP/visible/train/060510.jpg
# Image loaded successfully: LLVIP/visible/train/060513.jpg
# Image loaded successfully: LLVIP/visible/train/070013.jpg
# Image loaded successfully: LLVIP/visible/train/070020.jpg
# Image loaded successfully: LLVIP/visible/train/070023.jpg
# Image loaded successfully: LLVIP/visible/train/070026.jpg
# Image loaded successfully: LLVIP/visible/train/070046.jpg
# Image loaded successfully: LLVIP/visible/train/070084.jpg
# Image loaded successfully: LLVIP/visible/train/070090.jpg
# Image loaded successfully: LLVIP/visible/train/070112.jpg
# Image loaded successfully: LLVIP/visible/train/070143.jpg
# Image loaded successfully: LLVIP/visible/train/070147.jpg
# Image loaded successfully: LLVIP/visible/train/070154.jpg
# Image loaded successfully: LLVIP/visible/train/070170.jpg
# Image loaded successfully: LLVIP/visible/train/070180.jpg
# Image loaded successfully: LLVIP/visible/train/070187.jpg
# Image loaded successfully: LLVIP/visible/train/070190.jpg
# Image loaded successfully: LLVIP/visible/train/070192.jpg
# Image loaded successfully: LLVIP/visible/train/070204.jpg
# Image loaded successfully: LLVIP/visible/train/070216.jpg
# Image loaded successfully: LLVIP/visible/train/070227.jpg
# Image loaded successfully: LLVIP/visible/train/070231.jpg
# Image loaded successfully: LLVIP/visible/train/070232.jpg
# Image loaded successfully: LLVIP/visible/train/070238.jpg
# Image loaded successfully: LLVIP/visible/train/070247.jpg
# Image loaded successfully: LLVIP/visible/train/070258.jpg
# Image loaded successfully: LLVIP/visible/train/070259.jpg
# Image loaded successfully: LLVIP/visible/train/070260.jpg
# Image loaded successfully: LLVIP/visible/train/070266.jpg
# Image loaded successfully: LLVIP/visible/train/070269.jpg
# Image loaded successfully: LLVIP/visible/train/070275.jpg
# Image loaded successfully: LLVIP/visible/train/070292.jpg
# Image loaded successfully: LLVIP/visible/train/070293.jpg
# Image loaded successfully: LLVIP/visible/train/070321.jpg
# Image loaded successfully: LLVIP/visible/train/070344.jpg
# Image loaded successfully: LLVIP/visible/train/070346.jpg
# Image loaded successfully: LLVIP/visible/train/070358.jpg
# Image loaded successfully: LLVIP/visible/train/070389.jpg
# Image loaded successfully: LLVIP/visible/train/070390.jpg
# Image loaded successfully: LLVIP/visible/train/070425.jpg
# Image loaded successfully: LLVIP/visible/train/070431.jpg
# Image loaded successfully: LLVIP/visible/train/070436.jpg
# Image loaded successfully: LLVIP/visible/train/070444.jpg
# Image loaded successfully: LLVIP/visible/train/080020.jpg
# Image loaded successfully: LLVIP/visible/train/080021.jpg
# Image loaded successfully: LLVIP/visible/train/080025.jpg
# Image loaded successfully: LLVIP/visible/train/080034.jpg
# Image loaded successfully: LLVIP/visible/train/080053.jpg
# Image loaded successfully: LLVIP/visible/train/080061.jpg
# Image loaded successfully: LLVIP/visible/train/080064.jpg
# Image loaded successfully: LLVIP/visible/train/080074.jpg
# Image loaded successfully: LLVIP/visible/train/080079.jpg
# Image loaded successfully: LLVIP/visible/train/080090.jpg
# Image loaded successfully: LLVIP/visible/train/080094.jpg
# Image loaded successfully: LLVIP/visible/train/080107.jpg
# Image loaded successfully: LLVIP/visible/train/080111.jpg
# Image loaded successfully: LLVIP/visible/train/080126.jpg
# Image loaded successfully: LLVIP/visible/train/080129.jpg
# Image loaded successfully: LLVIP/visible/train/080152.jpg
# Image loaded successfully: LLVIP/visible/train/080154.jpg
# Image loaded successfully: LLVIP/visible/train/080172.jpg
# Image loaded successfully: LLVIP/visible/train/080177.jpg
# Image loaded successfully: LLVIP/visible/train/080196.jpg
# Image loaded successfully: LLVIP/visible/train/080228.jpg
# Image loaded successfully: LLVIP/visible/train/080231.jpg
# Image loaded successfully: LLVIP/visible/train/080239.jpg
# Image loaded successfully: LLVIP/visible/train/080240.jpg
# Image loaded successfully: LLVIP/visible/train/080250.jpg
# Image loaded successfully: LLVIP/visible/train/080254.jpg
# Image loaded successfully: LLVIP/visible/train/080264.jpg
# Image loaded successfully: LLVIP/visible/train/080265.jpg
# Image loaded successfully: LLVIP/visible/train/080272.jpg
# Image loaded successfully: LLVIP/visible/train/080290.jpg
# Image loaded successfully: LLVIP/visible/train/080297.jpg
# Image loaded successfully: LLVIP/visible/train/080308.jpg
# Image loaded successfully: LLVIP/visible/train/080320.jpg
# Image loaded successfully: LLVIP/visible/train/080332.jpg
# Image loaded successfully: LLVIP/visible/train/080362.jpg
# Image loaded successfully: LLVIP/visible/train/080371.jpg
# Image loaded successfully: LLVIP/visible/train/080373.jpg
# Image loaded successfully: LLVIP/visible/train/080379.jpg
# Image loaded successfully: LLVIP/visible/train/080383.jpg
# Image loaded successfully: LLVIP/visible/train/080387.jpg
# Image loaded successfully: LLVIP/visible/train/080392.jpg
# Image loaded successfully: LLVIP/visible/train/080404.jpg
# Image loaded successfully: LLVIP/visible/train/080430.jpg
# Image loaded successfully: LLVIP/visible/train/080436.jpg
# Image loaded successfully: LLVIP/visible/train/080458.jpg
# Image loaded successfully: LLVIP/visible/train/080467.jpg
# Image loaded successfully: LLVIP/visible/train/080474.jpg
# Image loaded successfully: LLVIP/visible/train/080480.jpg
# Image loaded successfully: LLVIP/visible/train/080522.jpg
# Image loaded successfully: LLVIP/visible/train/080533.jpg
# Image loaded successfully: LLVIP/visible/train/080546.jpg
# Image loaded successfully: LLVIP/visible/train/080547.jpg
# Image loaded successfully: LLVIP/visible/train/080551.jpg
# Image loaded successfully: LLVIP/visible/train/080559.jpg
# Image loaded successfully: LLVIP/visible/train/080561.jpg
# Image loaded successfully: LLVIP/visible/train/080565.jpg
# Image loaded successfully: LLVIP/visible/train/080581.jpg
# Image loaded successfully: LLVIP/visible/train/080583.jpg
# Image loaded successfully: LLVIP/visible/train/080585.jpg
# Image loaded successfully: LLVIP/visible/train/080588.jpg
# Image loaded successfully: LLVIP/visible/train/080603.jpg
# Image loaded successfully: LLVIP/visible/train/080611.jpg
# Image loaded successfully: LLVIP/visible/train/080616.jpg
# Image loaded successfully: LLVIP/visible/train/080618.jpg
# Image loaded successfully: LLVIP/visible/train/080621.jpg
# Image loaded successfully: LLVIP/visible/train/080645.jpg
# Image loaded successfully: LLVIP/visible/train/080647.jpg
# Image loaded successfully: LLVIP/visible/train/080657.jpg
# Image loaded successfully: LLVIP/visible/train/080667.jpg
# Image loaded successfully: LLVIP/visible/train/080668.jpg
# Image loaded successfully: LLVIP/visible/train/080671.jpg
# Image loaded successfully: LLVIP/visible/train/080701.jpg
# Image loaded successfully: LLVIP/visible/train/080704.jpg
# Image loaded successfully: LLVIP/visible/train/080723.jpg
# Image loaded successfully: LLVIP/visible/train/080727.jpg
# Image loaded successfully: LLVIP/visible/train/080732.jpg
# Image loaded successfully: LLVIP/visible/train/080740.jpg
# Image loaded successfully: LLVIP/visible/train/080742.jpg
# Image loaded successfully: LLVIP/visible/train/080747.jpg
# Image loaded successfully: LLVIP/visible/train/080750.jpg
# Image loaded successfully: LLVIP/visible/train/080751.jpg
# Image loaded successfully: LLVIP/visible/train/080757.jpg
# Image loaded successfully: LLVIP/visible/train/080759.jpg
# Image loaded successfully: LLVIP/visible/train/080763.jpg
# Image loaded successfully: LLVIP/infrared/train/081157.jpg
# Image loaded successfully: LLVIP/infrared/train/081168.jpg
# Image loaded successfully: LLVIP/infrared/train/081172.jpg
# Image loaded successfully: LLVIP/infrared/train/081173.jpg
# Image loaded successfully: LLVIP/infrared/train/081180.jpg
# Image loaded successfully: LLVIP/infrared/train/081194.jpg
# Image loaded successfully: LLVIP/infrared/train/081195.jpg
# Image loaded successfully: LLVIP/infrared/train/081214.jpg
# Image loaded successfully: LLVIP/infrared/train/081221.jpg
# Augmented Images array shape: (2000, 256, 256, 3)
# Augmented Labels array shape: (2000, 256, 256, 3)

# %%
# Split data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(augmented_labels_data, augmented_imgs_data, test_size=0.1, random_state=42)

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[120])

# %%
plt.imshow(y_train[120])

# %%
# !pip install -q git+https://github.com/tensorflow/examples.git
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for tensorflow-examples (setup.py) ... done

# %%
import tensorflow as tf
import numpy as np
from tensorflow_examples.models.pix2pix import pix2pix
import os
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output

AUTOTUNE = tf.data.AUTOTUNE

# Define your dataset shapes
X_train_shape = (X_train.shape[0], 256, 256, 3)
X_val_shape = (X_val.shape[0], 256, 256, 3)
y_train_shape = (y_train.shape[0], 256, 256, 3)
y_val_shape = (y_val.shape[0], 256, 256, 3)

# Define constants
BUFFER_SIZE = 1000
BATCH_SIZE = 1
IMG_WIDTH = 256
IMG_HEIGHT = 256
OUTPUT_CHANNELS = 3  # Number of channels in the output images (RGB)

# Create TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))

train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# Define the generator and discriminator networks
def build_generator():
    return pix2pix.unet_generator(OUTPUT_CHANNELS, norm_type='instancenorm')

def build_discriminator():
    return pix2pix.discriminator(norm_type='instancenorm', target=False)

# Define loss functions
LAMBDA = 10
loss_obj = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real, generated):
    real_loss = loss_obj(tf.ones_like(real), real)
    generated_loss = loss_obj(tf.zeros_like(generated), generated)
    total_disc_loss = real_loss + generated_loss
    return total_disc_loss * 0.5

def generator_loss(generated):
    return loss_obj(tf.ones_like(generated), generated)

def calc_cycle_loss(real_image, cycled_image):
    loss = tf.reduce_mean(tf.abs(real_image - cycled_image))
    return LAMBDA * loss

def identity_loss(real_image, same_image):
    loss = tf.reduce_mean(tf.abs(real_image - same_image))
    return LAMBDA * 0.5 * loss

# Define optimizers
generator_g_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
generator_f_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_x_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_y_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# Define the CCGAN model
def build_ccgan(generator_g, generator_f, discriminator_x, discriminator_y):
    input_thermal = tf.keras.layers.Input(shape=[IMG_HEIGHT, IMG_WIDTH, 3])
    input_rgb = tf.keras.layers.Input(shape=[IMG_HEIGHT, IMG_WIDTH, 3])

    # Generator G translates thermal to RGB
    fake_rgb = generator_g(input_thermal)

    # Generator F translates RGB to thermal
    fake_thermal = generator_f(input_rgb)

    # Identity mapping
    thermal_identity = generator_f(input_thermal)
    rgb_identity = generator_g(input_rgb)

    # Discriminators
    discriminator_x_output = discriminator_x(input_rgb)
    discriminator_y_output = discriminator_y(input_thermal)

    # Build and compile the model
    model = tf.keras.models.Model(inputs=[input_thermal, input_rgb],
                                  outputs=[fake_rgb, fake_thermal,
                                           thermal_identity, rgb_identity,
                                           discriminator_x_output, discriminator_y_output])
    return model

# Initialize the CCGAN model
generator_g = build_generator()
generator_f = build_generator()
discriminator_x = build_discriminator()
discriminator_y = build_discriminator()

ccgan_model = build_ccgan(generator_g, generator_f, discriminator_x, discriminator_y)

# %%
checkpoint_path = "./checkpoints_cgan_llvip_5/train"

ckpt = tf.train.Checkpoint(generator_g=generator_g,
                           generator_f=generator_f,
                           discriminator_x=discriminator_x,
                           discriminator_y=discriminator_y,
                           generator_g_optimizer=generator_g_optimizer,
                           generator_f_optimizer=generator_f_optimizer,
                           discriminator_x_optimizer=discriminator_x_optimizer,
                           discriminator_y_optimizer=discriminator_y_optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# If a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print('Latest checkpoint restored!!')

EPOCHS = 50

# Define a function to generate and display images
def generate_images(model, test_input):
    prediction = model(test_input)
    plt.figure(figsize=(12, 12))
    display_list = [test_input[0], prediction[0]]
    title = ['Input Image', 'Predicted Image']
    for i in range(2):
        plt.subplot(1, 2, i + 1)
        plt.title(title[i])
        # Getting the pixel values between [0, 1] to plot it.
        plt.imshow(display_list[i] * 0.5 + 0.5)
        plt.axis('off')
    plt.show()

# Define the training step
@tf.function
def train_step(real_thermal, real_rgb):
    with tf.GradientTape(persistent=True) as tape:
        # Generator G translates thermal to RGB
        fake_rgb = generator_g(real_thermal, training=True)
        # Generator F translates RGB to thermal
        fake_thermal = generator_f(real_rgb, training=True)

        # Discriminator X differentiates real RGB images and generated RGB images
        disc_real_rgb = discriminator_x(real_rgb, training=True)
        disc_fake_rgb = discriminator_x(fake_rgb, training=True)

        # Discriminator Y differentiates real thermal images and generated thermal images
        disc_real_thermal = discriminator_y(real_thermal, training=True)
        disc_fake_thermal = discriminator_y(fake_thermal, training=True)

        # Calculate the losses
        gen_g_loss = generator_loss(disc_fake_rgb)
        gen_f_loss = generator_loss(disc_fake_thermal)
        total_cycle_loss = calc_cycle_loss(real_thermal, fake_thermal) + calc_cycle_loss(real_rgb, fake_rgb)
        identity_loss_thermal = identity_loss(real_thermal, generator_f(real_thermal))
        identity_loss_rgb = identity_loss(real_rgb, generator_g(real_rgb))
        total_gen_g_loss = gen_g_loss + total_cycle_loss + identity_loss_thermal
        total_gen_f_loss = gen_f_loss + total_cycle_loss + identity_loss_rgb
        disc_x_loss = discriminator_loss(disc_real_rgb, disc_fake_rgb)
        disc_y_loss = discriminator_loss(disc_real_thermal, disc_fake_thermal)

    # Calculate the gradients for generator and discriminator
    generator_g_gradients = tape.gradient(total_gen_g_loss, generator_g.trainable_variables)
    generator_f_gradients = tape.gradient(total_gen_f_loss, generator_f.trainable_variables)
    discriminator_x_gradients = tape.gradient(disc_x_loss, discriminator_x.trainable_variables)
    discriminator_y_gradients = tape.gradient(disc_y_loss, discriminator_y.trainable_variables)

    # Apply the gradients to the optimizer
    generator_g_optimizer.apply_gradients(zip(generator_g_gradients, generator_g.trainable_variables))
    generator_f_optimizer.apply_gradients(zip(generator_f_gradients, generator_f.trainable_variables))
    discriminator_x_optimizer.apply_gradients(zip(discriminator_x_gradients, discriminator_x.trainable_variables))
    discriminator_y_optimizer.apply_gradients(zip(discriminator_y_gradients, discriminator_y.trainable_variables))

    return gen_g_loss, gen_f_loss, disc_x_loss, disc_y_loss


# Lists to store loss values
gen_g_loss_history = []
gen_f_loss_history = []
disc_x_loss_history = []
disc_y_loss_history = []

# Training loop
for epoch in range(EPOCHS):
    start = time.time()
    for image_thermal, image_rgb in train_dataset:
        gen_g_loss, gen_f_loss, disc_x_loss, disc_y_loss = train_step(image_thermal, image_rgb)

        # Append losses to history
        gen_g_loss_history.append(gen_g_loss)
        gen_f_loss_history.append(gen_f_loss)
        disc_x_loss_history.append(disc_x_loss)
        disc_y_loss_history.append(disc_y_loss)

    # Generate and display images after every epoch
    for image_thermal, image_rgb in val_dataset.take(1):
        generate_images(generator_g, image_thermal)

    # Save checkpoint every 5 epochs
    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print('Saving checkpoint for epoch {} at {}'.format(epoch + 1, ckpt_save_path))

    print('Time taken for epoch {} is {} sec\n'.format(epoch + 1, time.time() - start))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#This is after 100 epochs

# Plot generator G and F loss in one graph
plt.figure(figsize=(10, 5))
plt.plot(gen_g_loss_history, label='Generator G Loss')
plt.plot(gen_f_loss_history, label='Generator F Loss')
plt.xlabel('Batch')
plt.ylabel('Loss')
plt.title('Generator G and F Loss Curves')
plt.legend()
plt.grid(True)
plt.show()

# Plot discriminator X and Y loss in another graph
plt.figure(figsize=(10, 5))
plt.plot(disc_x_loss_history, label='Discriminator X Loss')
plt.plot(disc_y_loss_history, label='Discriminator Y Loss')
plt.xlabel('Batch')
plt.ylabel('Loss')
plt.title('Discriminator X and Y Loss Curves')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

# Load the checkpoint
checkpoint_path = "./checkpoints_cgan_llvip_5/train"
ckpt = tf.train.Checkpoint(generator_g=generator_g)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# If a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print('Latest checkpoint restored!!')
else:
    print("Checkpoint not found. Make sure you have trained the generator model and saved the checkpoints.")

# Function to make predictions
def generate_images(model, test_input):
    prediction = model(test_input, training=True)
    return prediction

# Choose sample indices for prediction
sample_indices = [1,8,3,9]  # Assuming you want to predict for the 3rd, 6th, and 9th images in the validation set

plt.figure(figsize=(25, 15))

for i, sample_index in enumerate(sample_indices):
    # Load the input thermal image and ground truth RGB image for prediction
    sample_thermal_image = X_val[sample_index:sample_index+1]
    ground_truth_rgb_image = y_val[sample_index:sample_index+1]  # Assuming Y_val contains ground truth RGB images

    # Generate RGB image predictions
    predicted_rgb_image = generate_images(generator_g, sample_thermal_image)

    # Plot the original thermal image, predicted RGB image, and ground truth RGB image
    plt.subplot(len(sample_indices), 3, i*3 + 1)
    plt.title('Original Thermal Image {}'.format(i+1))
    plt.imshow(sample_thermal_image[0])

    plt.subplot(len(sample_indices), 3, i*3 + 2)
    plt.title('Predicted RGB Image {}'.format(i+1))
    plt.imshow(predicted_rgb_image[0])

    plt.subplot(len(sample_indices), 3, i*3 + 3)
    plt.title('Ground Truth RGB Image {}'.format(i+1))
    plt.imshow(ground_truth_rgb_image[0])

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
